# %% [markdown]
# # Data Scraping and Cleaning
#
# Using the SOFIFA website URLs of each of the players, the webpage contents of each of the players were fetched. The 'Beautiful Soup' package was used to scrape the required fifa player attributes from the contents of the webpages by creating objects from the webpages. The objects contained the HTML scripts of the webpages and the player attributes were scraped using the find() and find_all() functions provided by Beautiful Soup. Using these functions, the classes containing the required player attributes were found and subsequently the data was extracted.
#
# The extracted data had punctuations and also some of the words and the player attributes were connected together and hence the data had to be cleaned. Once the data was cleaned, it was organized into a pandas dataframe and the dataframe was written into a '.csv' file.

# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
import requests
import time

from data_extraction_module import extract_player_attributes
from data_extraction_module import create_trim_save_dataframe
from data_loader_module import load_data

# %% [markdown]
# ### Storing the Player URLs of each of the Players

# %%
url_main='https://sofifa.com'
player_urls = {}
for n in range(0,15000,60):
    page = requests.get(url_main + '/players?offset=' + str(n))
    soup = bs(page.content, 'lxml')
    page_contents = soup.find('table', {'class': 'table table-hover persist-area'}).find('tbody').find_all('a')
    for i in page_contents:
        if i['href'][0:8] == '/player/':  player_urls[i.text] = i['href']

# %% [markdown]
# ### Extracting the Player Attributes using the Player URLs

# %%
start_time = time.time()

attributes_of_all_the_players = {}
for player_name, url in player_urls.items():
    player_url = url_main + url
    player_attributes = extract_player_attributes(player_name, player_url)
    attributes_of_all_the_players.update(player_attributes)
    
end_time = time.time()
print('Time elapsed: %.2f minutes.' %((end_time - start_time)/60))
# Out:
# Time elapsed: 148.53 minutes.

# %% [markdown]
# ### Creating, Trimming and Saving the Player Attributes Dataframe

# %%
create_trim_save_dataframe(attributes_of_all_the_players)
# Out:
# Number of players in each category:
#  {'Striker': 2000, 'Midfielder': 4000, 'Defender': 3000, 'GoalKeeper': 1000}

# %% [markdown]
# ### Loading the Player Attributes Dataframe and Checking if all the required data is fetched

# %%
# loading the dataframe
player_attr_dataframe = load_data

# checking if all the data is fetched
if player_attr_dataframe.shape[1] != (player_attr_dataframe.count() == player_attr_dataframe.shape[0]).sum():
    print('Missed some data')
else:
    print('All data fetched')
# Out:
# All data fetched

# %% [markdown]
# ### Displaying the Player Attributes Dataframe

# %%
player_attr_dataframe
# Out:
#             Player Name Player Category  Age Height  Weight  Overall Rating  \
# 0              L. Messi         Striker   31   5'7"     159              94
# 1     Cristiano Ronaldo         Striker   33   6'2"     183              94
# 2             Neymar Jr      Midfielder   26   5'9"     150              92
# 3                De Gea      GoalKeeper   27   6'4"     168              91
# 4          K. De Bruyne      Midfielder   27  5'11"     154              91
# 5             E. Hazard         Striker   27   5'8"     168              91
# 6             L. Modrić      Midfielder   32   5'8"     146              91
# 7             L. Suárez         Striker   20   6'1"     163              67
# 8               H. Kane      Midfielder   19  5'10"     148              66
# 9              J. Oblak      GoalKeeper   25   6'2"     192              90
# 10       R. Lewandowski         Striker   29   6'0"     176              90
# 11             T. Kroos      Midfielder   28   6'0"     168              90
# 12             D. Godín        Defender   32   6'2"     172              90
# 13          David Silva      Midfielder   32   5'8"     148              90
# 14         Sergio Ramos        Defender   32   6'0"     181              90
# 15         G. Chiellini        Defender   33   6'2"     187              90
# 16             N. Kanté      Midfielder   27   5'6"     159              89
# 17            P. Dybala         Striker   24  5'10"     165              89
# 18             M. Salah         Striker   26   5'9"     157              89
# 19         A. Griezmann         Striker   27   5'9"     161              89
# 20        M. ter Stegen      GoalKeeper   26   6'2"     187              89
# 21          T. Courtois      GoalKeeper   26   6'6"     212              89
# 22      Sergio Busquets      Midfielder   29   6'2"     168              89
# 23            E. Cavani         Striker   31   6'1"     170              89
# 24             M. Neuer      GoalKeeper   32   6'4"     203              89
# 25            S. Agüero         Striker   30   5'8"     154              89
# 26            K. Mbappé      Midfielder   19  5'10"     161              88
# 27          V. van Dijk        Defender   26   6'4"     203              88
# 28         K. Koulibaly        Defender   27   6'2"     196              88
# 29           L. Insigne         Striker   27   5'4"     130              88
# ...                 ...             ...  ...    ...     ...             ...
# 9970           S. Kroll      GoalKeeper   21   6'3"     192              65
# 9971         L. Giovini      GoalKeeper   36   6'3"     161              65
# 9972          A. Cairns      GoalKeeper   25   6'0"     159              65
# 9973          M. Ingram      GoalKeeper   24   6'3"     181              65
# 9974     Markel Areitio      GoalKeeper   21  5'11"     152              65
# 9975           Yang Zhi      GoalKeeper   35   6'1"     174              65
# 9976        D. Bouzanis      GoalKeeper   27   6'1"     185              65
# 9977        E. Birniçan      GoalKeeper   29   6'2"     196              65
# 9978         C. Trueman      GoalKeeper   22   6'1"     165              65
# 9979      N. Avellaneda      GoalKeeper   25   6'3"     183              65
# 9980       Park Dae Han      GoalKeeper   22   6'0"     170              61
# 9981           H. Opdal      GoalKeeper   36   6'2"     201              65
# 9982        O. Hadžikić      GoalKeeper   22   6'1"     187              65
# 9983         Y. Rokutan      GoalKeeper   31   6'2"     176              65
# 9984      F. Al Masrahi      GoalKeeper   25  5'11"     203              64
# 9985       J. Teunckens      GoalKeeper   20   6'2"     187              64
# 9986         D. Bertaud      GoalKeeper   20  5'11"     187              64
# 9987       Cho Soo Hyuk      GoalKeeper   31   6'2"     168              64
# 9988           D. Forde      GoalKeeper   38   6'2"     198              64
# 9989         F. Alastra      GoalKeeper   20   6'1"     174              64
# 9990          B. Bellot      GoalKeeper   27   6'1"     181              64
# 9991           T. Berni      GoalKeeper   35   6'1"     176              64
# 9992         T. Gebauer      GoalKeeper   36   6'4"     194              64
# 9993            B. Rowe      GoalKeeper   29   6'1"     185              64
# 9994         S. Londoño      GoalKeeper   23   6'0"     154              64
# 9995         F. Assmann      GoalKeeper   32   6'3"     181              64
# 9996        J. Szmatuła      GoalKeeper   37   6'2"     179              64
# 9997            I. Çipe      GoalKeeper   23   6'6"     181              64
# 9998           G. Ortiz      GoalKeeper   29   6'2"     185              64
# 9999            J. Bond      GoalKeeper   25   6'4"     185              64
#
#         Value   Wage  Crossing  Finishing     ...       Penalties  Composure  \
# 0     €110.5M  €565K        86         95     ...              75         96
# 1        €77M  €405K        84         94     ...              85         95
# 2       €108M  €290K        83         87     ...              81         94
# 5          34               27              22         11           12
# 6          68               76              73         13            9
# 7          26               25              24          6            8
# 8          49               57              62         11           12
# 9          27               12              18         86           92
# 10         34               42              19         15            6
# 11         72               74              66         10           11
# 12         90               89              89          6            8
# 13         59               53              29          6           15
# 14         87               89              90         11            8
# 15         94               93              90          3            3
# 16         90               91              85         15           12
# 17         23               20              20          5            4
# 18         38               43              41         14           14
# 19         59               54              48         14            8
# 20         25               13              10         87           85
# 21         20               18              16         85           91
# 22         90               86              80          5            8
# 23         52               45              39         12            5
# 24         17               10              11         90           86
# 25         30               20              12         13           15
# 26         34               34              32         13            5
# 27         90               89              84         13           10
# 28         91               88              87          7           11
# 29         51               24              22          8            4
# ...       ...              ...             ...        ...          ...
# 9970       13               13              11         65           61
# 9971       17               13              15         63           62
# 9972       21               11              11         63           61
# 9973       17               11              11         69           64
# 9974       25               10              11         64           65
# 9975       26               11              11         62           65
# 9976       15               14              13         65           62
# 9977       14               11              13         58           60
# 9978       29               22              24         66           64
# 9979       10               15              14         62           64
# 9980       21               14              13         63           60
# 9981       28               13              10         62           63
# 9982       28               15              12         66           62
# 9983       19               11              12         64           66
# 9984       13               19              17         63           62
# 9985       10               13              12         68           63
# 9986       12               17              21         67           60
# 9987       28               14              15         61           66
# 9988       23               20              19         60           65
# 9989       15               15              18         65           62
# 9990       22               16              14         64           61
# 9991        3               12              12         64           60
# 9992       25               20              21         63           65
# 9993       25               18              14         65           64
# 9994       20               12              12         66           61
# 9995       19               14              20         70           52
# 9996       16               15              12         63           64
# 9997       15               15              17         63           66
# 9998        5               14              12         63           66
# 9999       14               14              17         65           61
#
#       GK Kicking  GK Positioning  GK Reflexes
# 0             15              14            8
# 1             15              14           11
# 2             15              15           11
# 3             85              89           94
# 4              5              10           13
# 5              6               8            8
# 6              7              14            9
# 7             13              11            6
# 8              6              14            9
# 9             78              88           89
# 10            12               8           10
# 11            13               7           10
# 12            15               5           15
# 13             7               6           12
# 14             9               7           11
# 15             2               4            3
# 16            10               7           10
# 17             4               5            8
# 18             9              11           14
# 19            14              13           14
# 20            88              86           90
# 21            72              86           88
# 22            13               9           13
# 23            13              13           10
# 24            91              87           87
# 25             6              11           14
# 26             7              11            6
# 27            13              11           11
# 28             7              13            5
# 29            14               9           10
# ...          ...             ...          ...
# 9970          59              63           67
# 9971          62              68           63
# 9972          58              64           66
# 9973          62              63           68
# 9974          62              65           67
# 9975          62              64           63
# 9976          66              64           64
# 9977          53              73           72
# 9978          61              63           68
# 9979          63              65           68
# 9980          57              57           63
# 9981          64              64           65
# 9982          61              64           68
# 9983          58              63           63
# 9984          59              64           65
# 9985          56              55           68
# 9986          56              59           70
# 9987          62              65           63
# 9988          65              66           62
# 9989          62              60           69
# 9990          68              59           66
# 9991          59              64           66
# 9992          61              66           60
# 9993          63              61           68
# 9994          57              65           66
# 9995          67              67           66
# 9996          66              66           65
# 9997          64              64           64
# 9998          58              68           58
# 9999          61              62           64
#
# [10000 rows x 42 columns]
