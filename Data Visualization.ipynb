# %% [markdown]
# # Data Visualization
#
# This file imports the functionalities from 'data_visualization_module.py' which are used for generating the plots for the Visualization of the FIFA Player Attributes. The plots generated include the 'Categorical Attributes Radar Plots', which are radar plots of attributes for each player category, 'Comprehensive Attributes Radar Plot' which is the radar plot comparing the attributes of the strikers, midfielders and defenders.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pylab import subplots
from math import pi

from data_visualization_module import *

# %% [markdown]
# ### Lists of Player Attributes, Titles and Number of Players used in the 'Categorical Attributes Radar Plots'

# %%
# List of Attributes
Attacking = ['Dribbling','Volleys','Finishing','Short Passing','Heading Accuracy']
MovementAndPower = ['Sprint Speed','Reactions','Positioning','Agility','Shot Power','Stamina']

Midfielding = ['Short Passing','Dribbling','Ball Control','Long Passing','Crossing']
PowerAndMentality = ['Long Shots','Stamina','Balance','Strength','Vision']

Defending = ['Marking','Standing Tackle','Sliding Tackle','Strength','Interceptions']

GoalKeeping = ['GK Diving','GK Handling','GK Kicking','GK Positioning','GK Reflexes']

attributes_by_category = {'Striker': [Attacking, MovementAndPower],
                          'Midfielder': [Midfielding, PowerAndMentality],
                          'Defender': [Defending],
                          'GoalKeeper': [GoalKeeping]}

# Parts of Titles for the Radar Plots 
title_parts = ['Attacking', 'Movement and Power', 'Midfielding','Power and Mentality','Defending','GoalKeeping']

# Number of Players by Category and Percentage
percentage = [5,20,50,100]
no_of_players_by_category = {'Striker': 2000, 'Midfielder': 4000, 'Defender': 3000, 'GoalKeeper': 1000}
no_of_players_by_percentage = {'Striker': [], 'Midfielder': [], 'Defender': [], 'GoalKeeper': []}

for category, number in no_of_players_by_category.items(): 
    no_of_players_by_percentage[category] = [int(p*number/100) for p in percentage]

# %% [markdown]
# ### Generation of the 'Categorical Attributes Radar Plots'

# %%
plot_count = 0
for category, attr_list in attributes_by_category.items():
    for attributes in attr_list:
        title_part = title_parts[plot_count]
        plot_count += 1
        categorical_attributes_radar_plot(category, attributes, percentage, no_of_players_by_percentage[category], title_part)

# %% [markdown]
# ### List of Attributes and Top Number of Players used in the 'Comprehensive Attributes Radar Plot'

# %%
comparison_attr_dict = {'Reactions':0, 'Passing':0, 'Sprint Speed':0, 'Finishing':0, 'Volleys':0,
                        'Strength':0, 'Stamina':0, 'Tackling':0, 'Interceptions':0}
comparison_attr_list = ['Reactions', 'Short Passing', 'Long Passing', 'Sprint Speed', 'Finishing', 'Volleys',
                        'Strength', 'Stamina', 'Standing Tackle', 'Sliding Tackle', 'Interceptions']
comparison_attr_map  = {'Passing':['Short Passing', 'Long Passing'], 'Tackling':['Standing Tackle', 'Sliding Tackle']}
number_top = 100

# %% [markdown]
# ### Generation of the 'Comprehensive Attributes Radar Plot'

# %%
comprehensive_attributes_radar_plot(comparison_attr_dict, comparison_attr_list, comparison_attr_map, number_top)

# %% [markdown]
#  ### Plot Pie Graph of Players' Catagrory'

# %%
draw_pie(player_attributes)

# %% [markdown]
# ### Value vs Rating

# %%
value_vs_rating(500)
# Out:
# C:\Users\z\Anaconda3\lib\site-packages\numpy\core\numeric.py:553: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
# C:\Users\z\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\z\Anaconda3\lib\site-packages\numpy\core\numeric.py:501: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\z\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:5155: ComplexWarning: Casting complex values to real discards the imaginary part
#   X[0] = start
# C:\Users\z\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:5156: ComplexWarning: Casting complex values to real discards the imaginary part
#   X[N + 1] = end
# C:\Users\z\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:5159: ComplexWarning: Casting complex values to real discards the imaginary part
#   X[1:N + 1, 1] = y1slice
# C:\Users\z\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:5161: ComplexWarning: Casting complex values to real discards the imaginary part
#   X[N + 2:, 1] = y2slice[::-1]

# %% [markdown]
# ### Distribution of Height/ Weight/ BMI

# %%
single_attribute_distribution('Hight (cm)')
# Out:
# C:\Users\z\Anaconda3\lib\site-packages\matplotlib\transforms.py:841: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# C:\Users\z\Anaconda3\lib\site-packages\matplotlib\transforms.py:2052: ComplexWarning: Casting complex values to real discards the imaginary part
#   x, y = float(x), float(y)
# C:\Users\z\Anaconda3\lib\site-packages\matplotlib\mlab.py:3780: ComplexWarning: Casting complex values to real discards the imaginary part
#   result[i] = np.sum(np.exp(-energy), axis=0)
# C:\Users\z\Anaconda3\lib\site-packages\numpy\core\numeric.py:501: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
single_attribute_distribution('Weight')
# Out:
# C:\Users\z\Anaconda3\lib\site-packages\matplotlib\transforms.py:841: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# C:\Users\z\Anaconda3\lib\site-packages\matplotlib\transforms.py:2052: ComplexWarning: Casting complex values to real discards the imaginary part
#   x, y = float(x), float(y)
# C:\Users\z\Anaconda3\lib\site-packages\matplotlib\mlab.py:3780: ComplexWarning: Casting complex values to real discards the imaginary part
#   result[i] = np.sum(np.exp(-energy), axis=0)
# C:\Users\z\Anaconda3\lib\site-packages\numpy\core\numeric.py:501: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
single_attribute_distribution('BMI')
# Out:
# C:\Users\z\Anaconda3\lib\site-packages\matplotlib\transforms.py:841: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# C:\Users\z\Anaconda3\lib\site-packages\matplotlib\transforms.py:2052: ComplexWarning: Casting complex values to real discards the imaginary part
#   x, y = float(x), float(y)
# C:\Users\z\Anaconda3\lib\site-packages\matplotlib\mlab.py:3780: ComplexWarning: Casting complex values to real discards the imaginary part
#   result[i] = np.sum(np.exp(-energy), axis=0)
# C:\Users\z\Anaconda3\lib\site-packages\numpy\core\numeric.py:501: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
list_of_wage_of_top([50,200,1000])

# %% [markdown]
# ### Attributes VS Height/ Weight/ BMI

# %%
playergroup1=pd.concat([strike_player,midfield_player,defend_player])
plot_height_weight_BMI('Movement',playergroup1)

# %%
plot_height_weight_BMI('Attacking+Skill',playergroup1)

# %%
plot_height_weight_BMI('Power',playergroup1)

# %%
playergroup2=pd.concat([midfield_player,defend_player])
plot_height_weight_BMI('Defending',playergroup2)

# %%
plot_height_weight_BMI('Goalkeeping',goalkeep_player)

# %%
AA=['Attacking']
MA=['Movement']
DA=['Defending']
GKA=['Goalkeeping']
PA=['Power']
MDA=['Midfielding']
AA2=['Crossing','Finishing','Heading Accuracy','Short Passing','Volleys','Attacking']
MA2=['Dribbling', 'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control',]
DA2=['Marking', 'Standing Tackle', 'Sliding Tackle']
GKA2=['GK Diving', 'GK Handling', 'GK Kicking', 'GK Positioning', 'GK Reflexes']
PA2=['Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots']
MDA2=['Short Passing', 'Dribbling', 'Ball Control', 'Long Passing', 'Crossing']

# %%
gpt=goalkeep_player.iloc[:200,:]
pWH(GKA,gpt,'top 200 GKs','Goalkeeping')

# %%
mpt=midfield_player.iloc[:500,:]
pWH(MDA,mpt,'top 500 Midfielders','Midfielding')

# %%
spt=strike_player.iloc[:500,:]
pWH(AA,spt,'top 500 Strikers','Attacking')

# %%
opt=playergroup1.sort_values('Overall Rating',ascending=False).head(1000)
pWH(MA,opt,'top 1000 FMD players','Movement')
pWH(PA,opt,'top 1000 FMD players','Power')

# %%
dpt=defend_player.iloc[:500,:]
pWH(DA,dpt,'top 500 Defenders','Defending')

# %%
wage([50,200,1000])
